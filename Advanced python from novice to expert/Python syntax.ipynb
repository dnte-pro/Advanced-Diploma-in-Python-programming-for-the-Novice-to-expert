# %% [markdown]
# # This are the basic Python syntax

# %%
x=2
y=5

print(y)
# Out:
# 5

# %%
b=1\
+4\
-1

print(b)
# Out:
# 4

# %% [markdown]
# # Writing line structure using semicolon

# %%
x=1; y=2; z=4

print(x); print(y); print(4)
# Out:
# 1
# 2
# 4

# %% [markdown]
# ## i) Comments

# %%
x=12
y=4
z=x-4 #this subtracts the number
"""
This is the first line of the comment
This is the second line
This is the third line"""

print(z)
# Out:
# 8

# %% [markdown]
# ## ii) Joining lines in python

# %%
x=8
y=8

z=x\
+5

print(z)
# Out:
# 13

# %% [markdown]
# ## iii) Multiple statements on a single line

# %%
x=5;y=13; z=y-x;print(z) #Not always preferred because of low code readability
# Out:
# 8

# %% [markdown]
# ## iv) Indentation

# %%
foo = long_function_name(var1,var2,
                          var3,var4)

# %%
def long_function_one(var_one,
        var_two, var_three, var_four):
    print(var_one)

# %% [markdown]
# # STRINGS OVERVIEW

# %% [markdown]
# ##### Here is how single or double quotations can affect the code

# %%
print("I'm not a programmer")
print('I\'m a programmer')
# Out:
# I'm not a programmer
# I'm a programmer

# %%
first_str = "This is the first line \nThis is the second line"
print(first_str)
# Out:
# This is the first line
# This is the second line

# %%
print("This is how the tab \t works")
# Out:
# This is how the tab 	 works

# %% [markdown]
# ## String Manipulation

# %%
first_str = "Kiprono_"
sir = " Kiprono_ Yegon"
sec_str = "Yegon"
name = first_str + sec_str

print(name)
# Out:
# Kiprono_Yegon

# %%
name = first_str*3
print(name)
# Out:
# Kiprono_Kiprono_Kiprono_

# %%
first_str in sec_str
# Out:
# False

# %%
sec_str in sir
# Out:
# True

# %%
sec_str.capitalize()
# Out:
# 'Yegon'

# %%
sec_str.lower()
# Out:
# 'yegon'

# %%
len(first_str)
# Out:
# 8

# %% [markdown]
# ### String Indexing

# %%
firstName = "Kiprono"
print(firstName[-1])
# Out:
# o

# %%
firstName = "Kiprono"
print(firstName[0])
# Out:
# K

# %%
firstName = "Kiprono"
print(firstName[9]) # The code gives an error because the number indexed is outside the number of characters in the string

# %% [markdown]
# ### String Slicing

# %%
string = "Kiprono is learning Python"
print(string)
# Out:
# Kiprono is learning Python

# %%
print(string[0])
# Out:
# K

# %%
print(string[0:8])
# Out:
# Kiprono

# %%
string.count("o")
# Out:
# 3

# %%
string.find("g")
# Out:
# 18

# %%
print(string[-6:-1])
# Out:
# Pytho

# %% [markdown]
# ## Boolean Expressions

# %%
x = True
type(x)
# Out:
# bool

# %%
x = 4
y = 8
(x == y)
# Out:
# False

# %% [markdown]
# ## Printing Function

# %%
string = "This is a string"
print(string)
# Out:
# This is a string

# %%
x = 3
print(x)
# Out:
# 3

# %%
print(f"The current value of X is {x}")
# Out:
# The current value of X is 3

# %%
string = "{first_name} is {action} python"
string.format(first_name = "Kiprono", action="reading")
# Out:
# 'Kiprono is reading python'

# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# #### Arithmetic operators

# %%
first_num = 5
sec_num = 3.0

#Add
result = first_num + sec_num

print(result)
print(type(result))
# Out:
# 8.0
# <class 'float'>

# %%
# substract 
result_subtract = first_num - sec_num
print(result_subtract)
print(type(result_subtract))
# Out:
# 2.0
# <class 'float'>

# %%
result_div = first_num / sec_num
print(result_div)
print(type(result_div))
# Out:
# 1.6666666666666667
# <class 'float'>

# %%
result_mul = first_num * sec_num
print(result_mul)
print(type(result_mul))
# Out:
# 15.0
# <class 'float'>

# %%
result_rem = first_num % sec_num
print(result_rem)
# Out:
# 2.0

# %%
result_divfloor = first_num // sec_num
print(result_divfloor)
# Out:
# 1.0

# %% [markdown]
# ### Comparison operators

# %%
fNum = 4
sNum = 5 

print(fNum == sNum)
# Out:
# False

# %%
fNum = 4
sNum = 5 

print(fNum != sNum)
# Out:
# True

# %%
fNum = 4
sNum = 5 
print(fNum >= sNum)
# Out:
# False

# %%
fNum = 4
sNum = 5 
print(fNum <= sNum)
# Out:
# True

# %% [markdown]
# #####  Rounding of in python

# %%
print((2.1 + 3.2) == 5.3)      #The output is False because of floating-point precision errors.
# Out:
# False

# %% [markdown]
# ##### Solving floating-point precision errors

# %%
print(2.1 + 3.2)
# Out:
# 5.300000000000001

# %%
print(5.300000000000001 ==5.3)
# Out:
# False

# %% [markdown]
# #### Logical Operators

# %%
x = 4 
y = 5
print( x == 5)
# Out:
# False

# %%
x = 4 
y = 5
print( not x == 5)
# Out:
# True

# %%
x = 4 
y = 5
print( x == 5 or y == 5)
# Out:
# True

# %%
x = 4 
y = 5
print( False or True)
# Out:
# True

# %%
x = 4 
y = 5
print(False and True)
# Out:
# False

# %%
empty_str = ""

bool(empty_str)
# Out:
# False

# %%
bool(empty_str) == False    #Checking "Equality" Topic on Truthiness and Equality
# Out:
# True

# %% [markdown]
# ### Identity Operators

# %%
x = 1000
y = 1000

print(x ==y) #Equality Operator, comparing VALUES
# Out:
# True

# %%
print(x is y) ##identity, comparing VARIABLES (MEMORY ADDRESS)
# Out:
# False

# %%
id(x)
# Out:
# 1789759757552

# %%
id(y)
# Out:
# 1789759759536

# %% [markdown]
# The above "is" returns False, but when a value of less than 256 is used then it returns true.

# %%
x = 100
y = 100

x is y
# Out:
# True

# %%
id(y)
id(x) #they share the same memory address
# Out:
# 140708409290760

# %% [markdown]
# ## Membership Operators

# %%
x = "Kiprono"
y = "Kiprono Yegon"

x in y
# Out:
# True

# %%
x not in y
# Out:
# False

# %% [markdown]
# ## Bitwise Operators

# %%
x = 3
y = 4

# %%
y = 0b100
int(y)
# Out:
# 4

# %%
print(x | y)
# Out:
# 7

# %%
 print(x & y)
# Out:
# 0

# %%
print(x ^ y)
# Out:
# 7

# %% [markdown]
# # Data Tyoes and Control Flow

# %% [markdown]
# ### Lists

# %%
my_list  = [1, 2.4, "Kiprono Loves playing 8", 8.8, True]
print(my_list)
print(type(my_list))
# Out:
# [1, 2.4, 'Kiprono Loves playing 8', 8.8, True]
# <class 'list'>

# %% [markdown]
# ##### List slicing

# %%
list = [1,2,3]
list[1] = "kiprono"
print(list)
# Out:
# [1, 'kiprono', 3]

# %% [markdown]
# ##### Lists are mutable(can be changed)

# %%
string = "Python course"
string[0] = "A"

#Gives an error

# %% [markdown]
# ### Tuples

# %%
#They are lists that are immutable
#Uses ()
tuple = (1, 2, 5.3)
print(tuple)
print(type(tuple))
# Out:
# (1, 2, 5.3)
# <class 'tuple'>

# %%
#When you try to slice it gives an error because it is immutable
tuple(1) = 4
print(tuple)

# %% [markdown]
# ### Sets

# %%
my_set = {1, 2, 3, "broski"}

# %%
my_set
# Out:
# {1, 2, 3, 'broski'}

# %%
print(type(my_set))
# Out:
# <class 'set'>

# %%
# Sets are list but with elements that are unique, and they cannot be indexed
#they are mutable
my_set = {1, 2, 3, 4}
my_set.add(5)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set = {1, 2, 3, 4}
my_set.pop()
# Out:
# 1

# %%
print(my_set)
# Out:
# {2, 3, 4}

# %%
my_set = {1,1,2,2,3,4}
my_set
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# sets do not repeat objects

# %% [markdown]
# # Dictionaries

# %%
# They are key-value pair data structures
my_dict = {1:2, "Kiprono":4, 2.3:["a",5,2.1]}
print(type(my_dict))
print(my_dict)
# Out:
# <class 'dict'>
# {1: 2, 'Kiprono': 4, 2.3: ['a', 5, 2.1]}

# %%
my_dict["Kiprono"]
# Out:
# 4

# %%
print("Hello")
print(my_dict[0]) #It gives an error becauset there is no key pair "0"
print("Hello")

# %%
print("Hello")
print(my_dict.get(0)) #the 'get' function helps to check if there is the key value pair written.
print("Hello")
# Out:
# Hello
# None
# Hello
