# %% [markdown]
# # Print the Welcome Message

# %%
print("Welcome to the first project! I am an application that takes a message and a letter from you. My task is to count how many times a letter has occurred and the percentage of the letter.")
# Out:
# Welcome to the first project! I am an application that takes a message and a letter from you. My task is to count how many times a letter has occurred and the percentage of the letter.

# %% [markdown]
# ## Get the user inputs

# %%
user_input = input("Please enter the message: ")
user_letter = input("Please enter a letter: ")
# Out:
# Please enter the message:  one of the goooooood poems
# Please enter a letter:  o

# %% [markdown]
# ## Count occurences

# %%
len(user_input) #counts how manu characters are in the string
# Out:
# 26

# %%
user_input.upper() # makes the whole string uppercase
# Out:
# 'ONE OF THE GOOOOOOOD POEMS'

# %%
user_input.lower() #makes the whole string lowercase
# Out:
# 'one of the goooooood poems'

# %%
user_input.count("o") #counts the occurrences of the letter given
# Out:
# 10

# %%
count = user_input.count("o")

# %%
print(count)
# Out:
# 10

# %% [markdown]
# ## Calculate the  percentage of the given letter

# %%
len_message = len(user_input)
percentage = count/len_message*100
print(percentage)
# Out:
# 38.46153846153847

# %% [markdown]
# ## Print the output to the user

# %%
    print("The count of", user_letter, "is ", count)
    print("The percentage of ", user_letter, "is", percenta)
# Out:
# The count of o is  10
