# %%
num = 1.0
print(type(num))
# Out:
# <class 'float'>

# %%
second_num = 12
print(type(second_num))
# Out:
# <class 'int'>

# %%
answer = True
print(type(answer))
# Out:
# <class 'bool'>

# %%
print(' I\'m a programmer')
# Out:
#  I'm a programmer
